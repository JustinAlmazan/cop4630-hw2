# %%
# 4862336
# Justin Almazan (Only)

# import libraries
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data_logistic.csv')
x1 = data.iloc[:, 0]
x2 = data.iloc[:, 1]
y = data.iloc[:, 2]
cdict = {0: 'gold', 1: 'black'}
n = len(x1)

for i in range(0, n):
    plt.scatter(x1[i], x2[i], color = cdict.get(y[i]))

plt.show()

# %%
def sigmoid(z):
    return (1.0/(1 + math.e**(-z)))

# %%
x_s = np.linspace(-5, 5, 1000)
y_s = sigmoid(x)

plt.plot(x_s, y_s)
plt.show()

# %%
def net_input(theta, x):
    return np.dot(x, theta)

def probability(theta, x):
    return sigmoid(net_input(theta, x))

def cost_function(self, theta, x, y):
    m = x.shape[0]
    total_cost = -(1/m) * np.sum(
        y * np.log(probability(theta, x)) + (1 - y) 
        * np.log(1 - probability(theta, x)))
    return total_cost

def cal_grad(theta, X, y):
    htheta = np.matmul(np.transpose(theta), X)
    term1 = np.matmul(np.transpose(X), (theta-y))
    grad = 1/y * term1
    
    return grad

X = np.c_[np.ones((80, 1)), x1, x2]
y = y[:, np.newaxis]
theta = np.zeros((X.shape[1], 1))

print(cal_cost(X, y, theta))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\justi\CLASSES\Fall 2023\COP 4630 - Artificial Intelligence\HW2\hw2.ipynb Cell 5 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/justi/CLASSES/Fall%202023/COP%204630%20-%20Artificial%20Intelligence/HW2/hw2.ipynb#W4sZmlsZQ%3D%3D?line=18'>19</a>     return grad
#      <a href='vscode-notebook-cell:/c%3A/Users/justi/CLASSES/Fall%202023/COP%204630%20-%20Artificial%20Intelligence/HW2/hw2.ipynb#W4sZmlsZQ%3D%3D?line=20'>21</a> X = np.c_[np.ones((80, 1)), x1, x2]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/justi/CLASSES/Fall%202023/COP%204630%20-%20Artificial%20Intelligence/HW2/hw2.ipynb#W4sZmlsZQ%3D%3D?line=21'>22</a> y = y[:, np.newaxis]
# ...
